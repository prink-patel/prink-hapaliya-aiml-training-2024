# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Automobile_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         205 non-null    int64
#  1   symboling          205 non-null    int64
#  2   normalized-losses  164 non-null    float64
#  3   make               205 non-null    object
#  4   fuel-type          205 non-null    object
#  5   aspiration         205 non-null    object
#  6   num-of-doors       203 non-null    object
#  7   body-style         205 non-null    object
#  8   drive-wheels       205 non-null    object
#  9   engine-location    205 non-null    object
#  10  wheel-base         205 non-null    float64
#  11  length             205 non-null    float64
#  12  width              205 non-null    float64
#  13  height             205 non-null    float64
#  14  curb-weight        205 non-null    int64
#  15  engine-type        205 non-null    object
# ...

# %% [markdown]
# #### From the given data set print the first and last five rows

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  symboling  normalized-losses   make fuel-type aspiration  \
# 200         200         -1               95.0  volvo       gas        std
# 201         201         -1               95.0  volvo       gas      turbo
# 202         202         -1               95.0  volvo       gas        std
# 203         203         -1               95.0  volvo    diesel      turbo
# 204         204         -1               95.0  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels engine-location  wheel-base  length  \
# 200         four      sedan          rwd           front       109.1   188.8
# 201         four      sedan          rwd           front       109.1   188.8
# 202         four      sedan          rwd           front       109.1   188.8
# 203         four      sedan          rwd           front       109.1   188.8
# 204         four      sedan          rwd           front       109.1   188.8
#
# ...

# %%
df.replace(['?','n.a'],np.nan,inplace=True)

# %%
df
# Out:
#      Unnamed: 0  symboling  normalized-losses         make fuel-type  \
# 0             0          3                NaN  alfa-romero       gas
# 1             1          3                NaN  alfa-romero       gas
# 2             2          1                NaN  alfa-romero       gas
# 3             3          2              164.0         audi       gas
# 4             4          2              164.0         audi       gas
# ..          ...        ...                ...          ...       ...
# 200         200         -1               95.0        volvo       gas
# 201         201         -1               95.0        volvo       gas
# 202         202         -1               95.0        volvo       gas
# 203         203         -1               95.0        volvo    diesel
# 204         204         -1               95.0        volvo       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df['price']= df['price'].fillna(0).astype('int')

# %%
df['price']
# Out:
# 0      13495
# 1      16500
# 2      16500
# 3      13950
# 4      17450
#        ...
# 200    16845
# 201    19045
# 202    21485
# 203    22470
# 204    22625
# Name: price, Length: 205, dtype: int64

# %%
df_max=df['price'].max()

# %%
df_max_make=df[df['price']==df_max]['make']
df_max_make
# Out:
# 74    mercedes-benz
# Name: make, dtype: object

# %% [markdown]
# Print All Toyota Cars details

# %%
pd.set_option('max_columns', 27)
df_toyota=df[df['make']=='toyota']
df_toyota
# Out:
#      Unnamed: 0  symboling  normalized-losses    make fuel-type aspiration  \
# 150         150          1               87.0  toyota       gas        std
# 151         151          1               87.0  toyota       gas        std
# 152         152          1               74.0  toyota       gas        std
# 153         153          0               77.0  toyota       gas        std
# 154         154          0               81.0  toyota       gas        std
# 155         155          0               91.0  toyota       gas        std
# 156         156          0               91.0  toyota       gas        std
# 157         157          0               91.0  toyota       gas        std
# 158         158          0               91.0  toyota    diesel        std
# 159         159          0               91.0  toyota    diesel        std
# 160         160          0               91.0  toyota       gas        std
# ...

# %% [markdown]
# Count total cars per company

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df_grop_car=df.groupby(['make']).count()
df_grop_car[df_grop_car.columns[0]]
# Out:
# make
# alfa-romero       3
# audi              7
# bmw               8
# chevrolet         3
# dodge             9
# honda            13
# isuzu             4
# jaguar            3
# mazda            17
# mercedes-benz     8
# mercury           1
# mitsubishi       13
# nissan           18
# peugot           11
# plymouth          7
# porsche           5
# renault           2
# saab              6
# subaru           12
# toyota           32
# volkswagen       12
# volvo            11
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# Find each company’s Highest price car

# %%
df_grop_car=df.groupby(['make'])
df_grop_car

# %%
df_grop_car['price'].max()
# Out:
# make
# alfa-romero      16500
# audi             23875
# bmw              41315
# chevrolet         6575
# dodge            12964
# honda            12945
# isuzu            11048
# jaguar           36000
# mazda            18344
# mercedes-benz    45400
# mercury          16503
# mitsubishi       14869
# nissan           19699
# peugot           18150
# plymouth         12764
# porsche          37028
# renault           9895
# saab             18620
# subaru           11694
# toyota           17669
# volkswagen       13845
# volvo            22625
# Name: price, dtype: int64

# %% [markdown]
# Find the average mileage of each car making company

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make fuel-type aspiration  \
# 0           0          3                NaN  alfa-romero       gas        std
# 1           1          3                NaN  alfa-romero       gas        std
# 2           2          1                NaN  alfa-romero       gas        std
# 3           3          2              164.0         audi       gas        std
# 4           4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  length  \
# 0          two  convertible          rwd           front        88.6   168.8
# 1          two  convertible          rwd           front        88.6   168.8
# 2          two    hatchback          rwd           front        94.5   171.2
# 3         four        sedan          fwd           front        99.8   176.6
# 4         four        sedan          4wd           front        99.4   176.6
#
# ...

# %%
df_mileage=df.groupby(['make'])['city-mpg'].mean()
df_mileage
# Out:
# make
# alfa-romero      20.333333
# audi             18.857143
# bmw              19.375000
# chevrolet        41.000000
# dodge            28.000000
# honda            30.384615
# isuzu            31.000000
# jaguar           14.333333
# mazda            25.705882
# mercedes-benz    18.500000
# mercury          19.000000
# mitsubishi       24.923077
# nissan           27.000000
# peugot           22.454545
# plymouth         28.142857
# porsche          17.400000
# renault          23.000000
# saab             20.333333
# subaru           26.333333
# toyota           27.500000
# volkswagen       28.583333
# volvo            21.181818
# Name: city-mpg, dtype: float64

# %%
df_mileage=df.groupby(['make'])['highway-mpg'].mean()
df_mileage
# Out:
# make
# alfa-romero      26.666667
# audi             24.142857
# bmw              25.375000
# chevrolet        46.333333
# dodge            34.111111
# honda            35.461538
# isuzu            36.000000
# jaguar           18.333333
# mazda            31.941176
# mercedes-benz    21.000000
# mercury          24.000000
# mitsubishi       31.153846
# nissan           32.944444
# peugot           26.636364
# plymouth         34.142857
# porsche          26.000000
# renault          31.000000
# saab             27.333333
# subaru           30.750000
# toyota           32.906250
# volkswagen       34.916667
# volvo            25.818182
# Name: highway-mpg, dtype: float64

# %% [markdown]
# Sort all cars by Price column

# %%
df_price_sort=df.sort_values(by=['price'])
df_price_sort
# Out:
#      Unnamed: 0  symboling  normalized-losses           make fuel-type  \
# 45           45          0                NaN          isuzu       gas
# 129         129          1                NaN        porsche       gas
# 44           44          1                NaN          isuzu       gas
# 9             9          0                NaN           audi       gas
# 138         138          2               83.0         subaru       gas
# ..          ...        ...                ...            ...       ...
# 17           17          0                NaN            bmw       gas
# 128         128          3                NaN        porsche       gas
# 73           73          0                NaN  mercedes-benz       gas
# 16           16          0                NaN            bmw       gas
# 74           74          1                NaN  mercedes-benz       gas
#
#     aspiration num-of-doors   body-style drive-wheels engine-location  \
# ...
